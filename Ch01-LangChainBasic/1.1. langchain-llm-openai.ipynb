# %% [markdown]
# # Package install
#
# - langchain-openai

# %%
# %pip install python-dotenv langchain-openai
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.3.0 (from langchain-openai)
#   Using cached langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Using cached openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached langsmith-0.7.33-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /Users/leehk/.pyenv/versions/tutorial-langchain/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (26.1)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading orjson-3.11.8-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading pydantic_core-2.46.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.4.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Downloading charset_normalizer-3.4.7-cp313-cp313-macosx_10_13_universal2.whl.metadata (40 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading langchain_openai-1.2.0-py3-none-any.whl (98 kB)
# Using cached langchain_core-1.3.0-py3-none-any.whl (515 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.7.33-py3-none-any.whl (378 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached openai-2.32.0-py3-none-any.whl (1.2 MB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp313-cp313-macosx_11_0_arm64.whl (314 kB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp313-cp313-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.5 MB/s  0:00:00 eta 0:00:01
# Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-macosx_11_0_arm64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 19.6 MB/s  0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (604 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading orjson-3.11.8-cp313-cp313-macosx_15_0_arm64.whl (128 kB)
# Downloading regex-2026.4.4-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp313-cp313-macosx_10_13_universal2.whl (309 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.4/640.4 kB 14.7 MB/s  0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, typing-extensions, tqdm, tenacity, sniffio, regex, pyyaml, python-dotenv, orjson, jsonpointer, jiter, idna, h11, distro, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, jsonpatch, httpcore, anyio, tiktoken, requests-toolbelt, pydantic, httpx, openai, langsmith, langchain-core, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [langchain-openai][langchain-openai]
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 certifi-2026.4.22 charset_normalizer-3.4.7 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 jiter-0.14.0 jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.3.0 langchain-openai-1.2.0 langsmith-0.7.33 openai-2.32.0 orjson-3.11.8 pydantic-2.13.3 pydantic-core-2.46.3 python-dotenv-1.2.2 pyyaml-6.0.3 regex-2026.4.4 requests-2.33.1 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.12.0 tqdm-4.67.3 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.3 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # API Key load

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Usage

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
response = llm.invoke("하이닉스 오늘 실적 발표 요약해줘.")

# %%
response.content
# Out:
# '하이닉스는 오늘 근로본 상승하는 실적을 발표했습니다. 매출액은 전년 동기 대비 20% 증가하여 10조 원을 기록했고, 영업이익은 2조 5천억 원으로 전년 동기 대비 50% 이상 증가했습니다. 이 같은 실적은 반도체 수요가 높아지고 가격이 상승한 데 기인한다고 하이닉스 측은 설명했습니다. 신종 코로나바이러스 감염증(코로나19) 등으로 불확실성이 높은 불안한 시기에도 수요가 높게 유지되며 기업 실적에 긍정적인 영향을 미쳤습니다.'
